# %%
states_and_capitals={
    'A':'1',
    'B':'2',
    'C':'3',
    'D':'4',
    'E':'5',
}
for k in states_and_capitals:
    print(states_and_capitals[k])
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
import csv 

with open("C:/Users/Lenovo/OneDrive/Desktop/Excel data/Data 1.csv","r") as file_object:
    data_table=csv.DictReader(file_object)
    for line in data_table:
        print(line)
# Out:
# {'Name': 'Following', 'Year': '1998', 'IMDB Score': '7.5', 'Budget': '6000', 'Gross Worldwide': '48482'}
# {'Name': 'Memento', 'Year': '2000', 'IMDB Score': '8.4', 'Budget': '9000000', 'Gross Worldwide': '39723096'}
# {'Name': 'Insomnia', 'Year': '2002', 'IMDB Score': '7.2', 'Budget': '46000000', 'Gross Worldwide': '113758770'}
# {'Name': 'Batman Begins', 'Year': '2005', 'IMDB Score': '8.2', 'Budget': '150000000', 'Gross Worldwide': '373413297'}
# {'Name': 'The Prestige', 'Year': '2006', 'IMDB Score': '8.5', 'Budget': '40000000', 'Gross Worldwide': '109676311'}
# {'Name': 'The Dark Knight', 'Year': '2008', 'IMDB Score': '9', 'Budget': '185000000', 'Gross Worldwide': '1004934033'}
# {'Name': 'Inception', 'Year': '2010', 'IMDB Score': '8.8', 'Budget': '160000000', 'Gross Worldwide': '829895144'}
# {'Name': 'The Dark Knight Rises', 'Year': '2012', 'IMDB Score': '8.4', 'Budget': '250000000', 'Gross Worldwide': '1081041287'}
# ...

# %%
import csv 

with open("C:/Users/Lenovo/OneDrive/Desktop/Excel data/Data 2.csv","r") as file_object:
    data_table=csv.DictReader(file_object)
    for line in data_table:
        print(line)
# Out:
# {'Video Name': 'Masha and The Bear - Recipe For Disaster', 'Channel Name': 'Masha and The Bear', 'Views': '561185827', 'Likes': '2.1M', '': ''}
# {'Video Name': 'Johny Johny Yes Papa - Great Songs for Children', 'Channel Name': "LooLoo Kids - Nursery Rhymes and Children's Songs", 'Views': '1020807584', 'Likes': '3.2M', '': ''}
# {'Video Name': 'Taylor Swift - Shake It Off', 'Channel Name': 'Taylor Swift', 'Views': '3210140604', 'Likes': '12M', '': ''}
# {'Video Name': 'Justin Bieber - Sorry (PURPOSE : The Movement)', 'Channel Name': 'Justin Bieber', 'Views': '3587835774', 'Likes': '15M', '': ''}
# {'Video Name': 'OneRepublic - Counting Stars', 'Channel Name': 'OneRepublic', 'Views': '3652787277', 'Likes': '16M', '': ''}
# {'Video Name': 'Katy Perry - Roar', 'Channel Name': 'Katy Perry', 'Views': '3659392210', 'Likes': '15M', '': ''}
# {'Video Name': 'Maroon 5 - Sugar', 'Channel Name': 'Maroon 5', 'Views': '3760434713', 'Likes': '15M', '': ''}
# ...

# %%
import csv
with open("C:/Users/Lenovo/OneDrive/Desktop/Excel data/Games.csv","r")as file_object:
    data_table =csv.reader(file_object)
    for row_of_excel in data_table:
        print(row_of_excel[0])
# Out:
# ï»¿Name
# PlayerUnknown's Battlegrounds
# Minecraft
# Diablo III
# Garry's Mod
# Terraria
# World of Warcraft
# Half-Life 2
# The Witcher 3: Wild Hunt
# StarCraft
# The Sims
# Fall Guys
# RollerCoaster Tycoon 3
# Half-Life
# Rust
# Civilization V
# The Sims 3
# Euro Truck Simulator 2
# Guild Wars
# StarCraft II: Wings of Liberty
# The Sims 2
# Valheim
# ARMA 3
# Last Ninja 2
# Cities: Skylines
# Guild Wars 2
# SimCity 3000
# The Forest
# Cyberpunk 2077
# DayZ
# Diablo II
# Populous
# RollerCoaster Tycoon
# The Last Ninja
# Warhammer 40,000: Dawn of WarÂ (including expansions)
# Where in the World Is Carmen Sandiego?
# Dark Souls
# Dark Souls III
# Age of Empires
# Civilization IV
# Command & Conquer
# Command & Conquer: Red Alert
# Crysis
# EverQuest
# Life Is Strange
# Theme Park
# Warcraft III: Reign of Chaos
# Dark Souls II
# Caesar II
# Caesar III
# Factorio
# Lords of the Realm II
# Myst
# Final Fantasy VII
# 7 Days to Die
# Age of Empires II: The Age of Kings
# ...

# %%
import csv
with open("C:/Users/Lenovo/OneDrive/Desktop/Excel data/insta.csv","r")as file_object:
    data_table =csv.reader(file_object)
    for row_of_excel in data_table:
        
            print(row_of_excel)
# Out:
# ['ï»¿rank', 'channel_info', 'influence_score', 'posts', 'followers', 'avg_likes', '60_day_eng_rate', 'new_post_avg_like', 'total_likes', 'country']
# ['1', 'cristiano', '92', '3.3k', '475.8m', '8.7m', '1.39%', '6.5m', '29.0b', 'Spain']
# ['2', 'kyliejenner', '91', '6.9k', '366.2m', '8.3m', '1.62%', '5.9m', '57.4b', 'United States']
# ['3', 'leomessi', '90', '0.89k', '357.3m', '6.8m', '1.24%', '4.4m', '6.0b', '']
# ['4', 'selenagomez', '93', '1.8k', '342.7m', '6.2m', '0.97%', '3.3m', '11.5b', 'United States']
# ['5', 'therock', '91', '6.8k', '334.1m', '1.9m', '0.20%', '665.3k', '12.5b', 'United States']
# ['6', 'kimkardashian', '91', '5.6k', '329.2m', '3.5m', '0.88%', '2.9m', '19.9b', 'United States']
# ['7', 'arianagrande', '92', '5.0k', '327.7m', '3.7m', '1.20%', '3.9m', '18.4b', 'United States']
# ['8', 'beyonce', '92', '2.0k', '272.8m', '3.6m', '0.76%', '2.0m', '7.4b', 'United States']
# ...

# %%
import csv
with open("C:/Users/Lenovo/OneDrive/Desktop/Excel data/IMDB.csv","r")as file_object:
    data_table =csv.reader(file_object)
    for row_of_excel in data_table:
                print(row_of_excel[1])
# Out:
# movie_name
# The Godfather
# The Silence of the Lambs
# Star Wars: Episode V - The Empire Strikes Back
# The Shawshank Redemption
# The Shining
# Casablanca
# One Flew Over the Cuckoo's Nest
# Indiana Jones and the Raiders of the Lost Ark
# The Lord of the Rings: The Return of the King
# Star Wars: Episode IV - A New Hope
# The Dark Knight
# The Godfather: Part II
# Aliens
# Schindler's List
# Inception
# The Lord of the Rings: The Fellowship of the Ring
# Alien
# Some Like It Hot
# Blade Runner
# Se7en
# Apocalypse Now
# 12 Angry Men
# The Lord of the Rings: The Two Towers
# Terminator 2: Judgment Day
# Star Wars: Episode VI - Return of the Jedi
# Die Hard
# Gone with the Wind
# Taxi Driver
# Pulp Fiction
# The Bridge on the River Kwai
# The Lion King
# North by Northwest
# Rear Window
# LÃ©on: The Professional
# Back to the Future
# Citizen Kane
# Goodfellas
# Memento
# American Beauty
# As Good as It Gets
# Forrest Gump
# Singin' in the Rain
# Braveheart
# Saving Private Ryan
# ...
